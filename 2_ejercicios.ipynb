# %% [markdown]
# # Analizando una Imagen

# %%
import matplotlib.pyplot as plt
img = plt.imread('beagle.jpg')
img.shape

img[10,10]
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_1381/3318591479.py in <cell line: 0>()
#       1 import matplotlib.pyplot as plt
# ----> 2 img = plt.imread('beagle.jpg')
#       3 img.shape
#       4
#       5 img[10,10]
#
# /usr/local/lib/python3.13/dist-packages/matplotlib/pyplot.py in imread(fname, format)
#    2611         fname: str | pathlib.Path | BinaryIO, format: str | None = None
#    2612 ) -> np.ndarray:
# -> 2613     return matplotlib.image.imread(fname, format)
#    2614
#    2615
#
# /usr/local/lib/python3.13/dist-packages/matplotlib/image.py in imread(fname, format)
#    1500             "``np.array(PIL.Image.open(urllib.request.urlopen(url)))``."
#    1501             )
# -> 1502     with img_open(fname) as image:
#    1503         return (_pil_png_to_float_array(image)
#    1504                 if isinstance(image, PIL.PngImagePlugin.PngImageFile) else
#
# /usr/local/lib/python3.13/dist-packages/PIL/Image.py in open(fp, mode, formats)
#    3511     if is_path(fp):
#    3512         filename = os.fspath(fp)
# -> 3513         fp = builtins.open(filename, "rb")
#    3514         exclusive_fp = True
#    3515     else:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'beagle.jpg'

# %%
rojo = img[10, 10, 0]
verde = img[10, 10, 1]
azul = img[10, 10, 2]

print("Rojo:", rojo)
print("Verde:", verde)
print("Azul:", azul)

# %%
print("Dimensiones:", img.shape)
print("Píxel [10,10]:", img[10,10])

plt.imshow(img)
plt.axis("off")
plt.show()

# %%
print("Valor mínimo:", img.min())
print("Valor máximo:", img.max())
print("Media:", img.mean())
print("Desviación estándar:", img.std())

# %%
plt.imshow(img[:, :, 0], cmap="Reds")
plt.colorbar()
plt.title("Canal Rojo")
plt.show()

# %%
plt.imshow(img[:, :, 1], cmap="Greens")
plt.colorbar()
plt.title("Canal Verde")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_1381/820582932.py in <cell line: 0>()
# ----> 1 plt.imshow(img[:, :, 1], cmap="Greens")
#       2 plt.colorbar()
#       3 plt.title("Canal Verde")
#       4 plt.show()
#
# NameError: name 'img' is not defined

# %%
plt.imshow(img[:, :, 2], cmap="Blues")
plt.colorbar()
plt.title("Canal Azul")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_1381/84674320.py in <cell line: 0>()
# ----> 1 plt.imshow(img[:, :, 2], cmap="Blues")
#       2 plt.colorbar()
#       3 plt.title("Canal Azul")
#       4 plt.show()
#
# NameError: name 'img' is not defined

# %%
media_rojo = img[:, :, 0].mean()
media_verde = img[:, :, 1].mean()
media_azul = img[:, :, 2].mean()

print("Rojo:", media_rojo)
print("Verde:", media_verde)
print("Azul:", media_azul)

# %%
canales = ["Rojo", "Verde", "Azul"]
valores = [media_rojo, media_verde, media_azul]

plt.bar(canales, valores)
plt.ylabel("Intensidad promedio")
plt.title("Color promedio de la imagen")
plt.show()

# %%
datos = img.reshape(-1, 3)

df = pd.DataFrame(
    datos,
    columns=["Rojo", "Verde", "Azul"]
)

print(df.head())

# %%
plt.hist(img[:,:,2].ravel(), bins=50)
plt.title("Distribución del canal azul")
plt.xlabel("Intensidad")
plt.ylabel("Frecuencia")
plt.show()
